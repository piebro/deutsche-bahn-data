# %%
import pandas as pd
df = pd.read_csv('../../data.csv', parse_dates=['arrival_planned_time', 'departure_planned_time'])
df.head()
# Out:
#       station train_name final_destination_station  delay_in_min  \
# 0  Aachen Hbf      RE 18                Aachen Hbf           6.0
# 1  Aachen Hbf      RB 33                Aachen Hbf           0.0
# 2  Aachen Hbf      RE 18                   Heerlen           0.0
# 3  Aachen Hbf       RE 4                Aachen Hbf           6.0
# 4  Aachen Hbf       RE 9                Aachen Hbf          17.0
#
#   arrival_planned_time  arrival_time_delta_in_min departure_planned_time  \
# 0  2024-05-10 00:45:00                        6.0                    NaT
# 1  2024-05-10 00:27:00                        0.0                    NaT
# 2                  NaT                        0.0    2024-05-10 00:17:00
# 3  2024-05-10 00:37:00                        6.0                    NaT
# 4  2024-05-10 00:41:00                       17.0                    NaT
#
#    departure_time_delta_in_min planned_platform changed_platform  is_canceled  \
# ...
